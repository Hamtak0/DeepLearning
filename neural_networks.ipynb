111328125, 12.010313987731934, 440.7708435058594, 121.79045867919922, 8.27712631225586, -55.044010162353516, -79.61087799072266, -39.03078079223633, 46.8863525390625, -271.3041076660156, -320.8000793457031, 435.5277099609375, 96.72985076904297, 408.7271423339844, 93.4684066772461, -15.952131271362305, 36.22296905517578, 55.657958984375, -180.0889434814453, 204.32997131347656, 457.0797424316406, -146.9400634765625, 157.7235565185547, 190.37867736816406, 477.10699462890625, -299.256591796875, 48.58473205566406, 432.314453125, 53.11518859863281, -177.70370483398438, -233.45504760742188, 64.128173828125, -100.53054809570312, -5.318727493286133, 182.06861877441406, 44.1242790222168, 166.0869598388672, 41.2272834777832, 63.46199417114258, -38.362972259521484, 24.487464904785156, 15.862971305847168, 467.56500244140625, -8.376680374145508, 363.96075439453125, 452.0752868652344, 429.5648498535156, -31.402851104736328, 104.51111602783203, 28.609394073486328, 189.72230529785156, 61.815185546875, -34.274391174316406, 381.3878479003906, -49.277217864990234, 44.321170806884766, 286.71051025390625, 447.58148193359375, 220.83261108398438, -153.12841796875, 255.57806396484375, 80.3559341430664, 3.695876121520996, 398.8706359863281, 460.0857238769531, 257.6540832519531, 233.84539794921875, 40.377899169921875, -8.221644401550293, -5.507939338684082, -96.82394409179688, -87.84837341308594, 58.86450958251953, 291.84521484375, -165.01864624023438, -2.4793484210968018, 416.3782653808594, 70.9383544921875, 85.34237670898438, 9.441033363342285, -14.612820625305176, 74.98735046386719, 28.660011291503906, 430.4078674316406, -28.914583206176758, -80.07176208496094, 473.966552734375, 342.44403076171875, -103.400390625, -209.70877075195312, -62.693359375, 23.245956420898438, 295.4332580566406, 49.9471435546875, -36.84516525268555, -2.8683929443359375, 471.6179504394531, -13.952075958251953, 288.4938049316406, -17.15461540222168, 35.645015716552734, 30.973217010498047, -62.14665985107422, 20.09228515625, 348.0222473144531, -144.97776794433594, -32.48429870605469, 473.2339782714844, 14.254497528076172, 550.8597412109375, -92.038818359375, -7.134330749511719, -20.9492244720459, 2.6165637969970703, -42.45941162109375, -40.647705078125]

x_points_tensor = torch.tensor(x_points_list, dtype=torch.float32)
y_points_tensor = torch.tensor(y_points_list, dtype=torch.float32)

x_train = x_points_tensor.view(-1, 1)
y_train = y_points_tensor.view(-1, 1)

# --- 2. Define the Neural Network ---
class Net(nn.Module):
  """A simple feed-forward neural network for regression."""
  def __init__(self):
    super(Net, self).__init__()
    # Define the sequence of layers
    self.main = nn.Sequential(
        nn.Linear(1, 32),
        nn.ReLU(),
        nn.Linear(32, 64),
        nn.ReLU(),
        nn.Linear(64, 16),
        nn.ReLU(),
        nn.Linear(16, 1)
    )

  def forward(self, x):
    """Defines the forward pass of the network."""
    return self.main(x)

# --- 3. Train the Network ---
# Instantiate the model
model = Net()

# Define the loss function: Mean Squared Error is standard for regression
criterion = nn.MSELoss()

# Define the optimizer: Adam is a popular and effective choice
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Set the number of training epochs
epochs = 5000

print("Starting training...")
# Training loop
for epoch in range(epochs):
  # Forward pass: compute predicted y by passing x to the model
  y_pred = model(x_train)

  # Compute the loss between predicted and actual values
  loss = criterion(y_pred, y_train)

  # Backward pass and optimization:
  # 1. Clear old gradients
  optimizer.zero_grad()
  # 2. Calculate gradients
  loss.backward()
  # 3. Update weights
  optimizer.step()

  # Print progress every 500 epochs
  if (epoch+1) % 500 == 0:
    print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')
print("Training finished.")

# --- 4. Visualize the Results ---
# Set the model to evaluation mode (disables dropout, etc.)
model.eval()

# Generate a smooth curve for plotting the learned function
with torch.no_grad(): # Disable gradient calculation for inference
    x_min, x_max = x_train[:, 0].min() + 0.1, x_train[:, 0].max() + 0.1
    x_curve = torch.linspace(x_min, x_max, 300).view(-1, 1)
    # Get the network's prediction for these values
    y_pred_curve = model(x_curve)

# Plot the points
plt.figure(figsize=(10, 8))

plt.scatter(x_points_tensor.numpy(), y_points_tensor.numpy(), label='Random Points')
plt.plot(x_curve.numpy(), y_pred_curve.numpy(), color='green', linewidth=2, label='Neural Network Fit')

plt.title('Random Points to Curve Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Starting training...
# Epoch [500/5000], Loss: 1484.8875
# Epoch [1000/5000], Loss: 1322.2822
# Epoch [1500/5000], Loss: 1194.0586
# Epoch [2000/5000], Loss: 1145.6655
# Epoch [2500/5000], Loss: 1117.7198
# Epoch [3000/5000], Loss: 1141.4315
# Epoch [3500/5000], Loss: 1129.2523
# Epoch [4000/5000], Loss: 1067.8159
# Epoch [4500/5000], Loss: 1056.6990
# Epoch [5000/5000], Loss: 1032.3163
# Training finished.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# Define the boundary function
def f(x):
  return np.sin(3 * x) + 0.4 * np.cos(7 * x) + 0.6 * x * np.exp(-0.5 * x**2) + 0.2 * x**3

# Generate random data
np.random.seed(0)
X = np.random.uniform(-2, 2, 150)
Y = np.random.uniform(-2.5, 2.5, 150)

# Create labels
labels = (Y > f(X)).astype(int)

# Plot the data
plt.figure(figsize=(8, 6))
plt.scatter(X[labels == 0], Y[labels == 0], color='blue', label='Class 0')
plt.scatter(X[labels == 1], Y[labels == 1], color='red', label='Class 1')

plt.title('Dataset with Two Classes and Two Features')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(loc='lower right')
plt.grid(True)

# Convert to PyTorch tensors
X_tensor = torch.from_numpy(X).float()
Y_tensor = torch.from_numpy(Y).float()
labels_tensor = torch.from_numpy(labels).float()

print("Dataset generated and plotted")
print("PyTorch tensors for X, Y, and labels are created.")
print("Shape of X_tensor:", X_tensor.shape)
print("Shape of Y_tensor:", Y_tensor.shape)
print("Shape of labels_tensor:", labels_tensor.shape)
# Out:
# Dataset generated and plotted
# PyTorch tensors for X, Y, and labels are created.
# Shape of X_tensor: torch.Size([150])
# Shape of Y_tensor: torch.Size([150])
# Shape of labels_tensor: torch.Size([150])

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# --- 1. Define generating function ---

# Define the boundary function
def f(x):
  return np.sin(3 * x) + 0.4 * np.cos(7 * x) + 0.6 * x * np.exp(-0.5 * x**2) + 0.2 * x**3

# Generate random data
np.random.seed(0)
X = np.random.uniform(-2, 2, 150)
Y = np.random.uniform(-2.5, 2.5, 150)

# Create labels
labels = (Y > f(X)).astype(int)

# Convert to PyTorch tensors and combine X and Y into a single input tensor
X_tensor = torch.from_numpy(X).float()
Y_tensor = torch.from_numpy(Y).float().view(-1, 1)
labels_tensor = torch.from_numpy(labels).float()

# --- 2. Define the Neural Network Architecture ---
class XORNet(nn.Module):
    def __init__(self):
        super(XORNet, self).__init__()
        self.layer1 = nn.Linear(2, 4)  # 2 input features, 4 hidden neurons
        self.layer2 = nn.Linear(4, 4)  # 4 hidden neurons, 4 output neuron
        self.layer3 = nn.Linear(4, 4)  # 4 hidden neurons, 4 output neuron
        self.layer4 = nn.Linear(4, 1)  # 4 hidden neurons, 4 output neuron

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.sigmoid(self.layer2(x))
        x = torch.relu(self.layer3(x))
        x = torch.sigmoid(self.layer4(x))
        return x

model = XORNet()
print("Model Architecture:\n", model)

# --- 3. Set Loss Function and Optimizer ---
loss_function = nn.BCELoss()  # Binary Cross-Entropy Loss
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# --- 4. Train the Model ---
epochs = 10000
losses = []

xy_tensor = torch.stack((X_tensor, Y_tensor.squeeze()), dim=1)

for i in range(epochs):
    # Forward pass
    y_pred = model(xy_tensor) # Use the combined input tensor

    # Calculate loss
    loss = loss_function(y_pred, labels_tensor.view(-1, 1)) # Use labels_tensor and reshape
    losses.append(loss.item())

    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (i + 1) % 1000 == 0:
        print(f'Epoch [{i+1}/{epochs}], Loss: {loss.item():.4f}')


# --- 5. Evaluate the Model ---
with torch.no_grad():
    predictions = (model(xy_tensor) > 0.5).float() # Use the combined input tensor
    accuracy = (predictions.eq(labels_tensor.view(-1, 1)).sum() / float(labels_tensor.shape[0])) * 100 # Compare with labels_tensor
    print(f'\nTraining Accuracy: {accuracy:.2f}%')


# --- 6. Visualize Results ---
plt.figure(figsize=(12, 5))

# Plot 1: Loss Curve
plt.subplot(1, 2, 1)
plt.plot(losses)
plt.title('Training Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')

# Plot 2: Decision Boundary
plt.subplot(1, 2, 2)
plt.title('Decision Boundary')
# Create a meshgrid of points to plot the boundary
h = .02  # step size in the mesh
x_min, x_max = X.min() - 0.1, X.max() + 0.1 # Use original numpy arrays for min/max
y_min, y_max = Y.min() - 0.1, Y.max() + 0.1 # Use original numpy arrays for min/max
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Predict the function value for the whole grid
grid_tensor = torch.FloatTensor(np.c_[xx.ravel(), yy.ravel()])
Z = model(grid_tensor)
Z = Z.reshape(xx.shape).detach().numpy()

# Plot the contour and training examples
plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.8)
plt.scatter(X[labels == 0], Y[labels == 0], c='blue', label='Class 0') # Use original numpy arrays for plotting
plt.scatter(X[labels == 1], Y[labels == 1], c='red', label='Class 1') # Use original numpy arrays for plotting
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.tight_layout()
plt.savefig('xor_classification.png')
# Out:
# Model Architecture:
#  XORNet(
#   (layer1): Linear(in_features=2, out_features=4, bias=True)
#   (layer2): Linear(in_features=4, out_features=4, bias=True)
#   (layer3): Linear(in_features=4, out_features=4, bias=True)
#   (layer4): Linear(in_features=4, out_features=1, bias=True)
# )
# Epoch [1000/10000], Loss: 0.2016
# Epoch [2000/10000], Loss: 0.1686
# Epoch [3000/10000], Loss: 0.0870
# Epoch [4000/10000], Loss: 0.0207
# Epoch [5000/10000], Loss: 0.0059
# Epoch [6000/10000], Loss: 0.0022
# Epoch [7000/10000], Loss: 0.0009
# Epoch [8000/10000], Loss: 0.0004
# Epoch [9000/10000], Loss: 0.0002
# Epoch [10000/10000], Loss: 0.0001
#
# Training Accuracy: 100.00%
